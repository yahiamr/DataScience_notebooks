# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Pokemon.csv')
df =df.drop(columns = 'Total')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# print(df.head())

# %%
df.columns 
# Printing the columns names
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name'][0:10] 
# Printing rows from 0 to 9 in the column 'Name'
# Out:
# 0                    Bulbasaur
# 1                      Ivysaur
# 2                     Venusaur
# 3        VenusaurMega Venusaur
# 4                   Charmander
# 5                   Charmeleon
# 6                    Charizard
# 7    CharizardMega Charizard X
# 8    CharizardMega Charizard Y
# 9                     Squirtle
# Name: Name, dtype: object

# %%
df[0:10]
# printing the rows from 0 to 9 in the selected dataframe
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.iloc[0:10,[1,4,5,6,7,8,9]]
# iloc is integer based locating api where u locate by the int value of the col and row like so:
# df.iloc[row_pos,col_pos]
# Out:
#                         Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0                  Bulbasaur  45      49       49       65       65     45
# 1                    Ivysaur  60      62       63       80       80     60
# 2                   Venusaur  80      82       83      100      100     80
# 3      VenusaurMega Venusaur  80     100      123      122      120     80
# 4                 Charmander  39      52       43       60       50     65
# 5                 Charmeleon  58      64       58       80       65     80
# 6                  Charizard  78      84       78      109       85    100
# 7  CharizardMega Charizard X  78     130      111      130       85    100
# 8  CharizardMega Charizard Y  78     104       78      159      115    100
# 9                   Squirtle  44      48       65       50       64     43

# %%
df.loc[0:10,['Type 1']]
# df.loc is label based locating api where u locate by the label of the col and row like so:
# df.loc[row_label,col_label]
# u can specify row range as so [0:100] as shown in this example
# Out:
#    Type 1
# 0   Grass
# 1   Grass
# 2   Grass
# 3   Grass
# 4    Fire
# 5    Fire
# 6    Fire
# 7    Fire
# 8    Fire
# 9   Water
# 10  Water

# %%
df.loc[(df['Type 1']=='Rock'),['Name','Attack']]
# with iloc u can filter ur data more powerfully searching for specific attributes and then show only the specifed
# columns as in this example i am showing onle the name and attack of the type rock heros
# Out:
#                           Name  Attack
# 80                     Geodude      80
# 81                    Graveler      95
# 82                       Golem     120
# 103                       Onix      45
# 149                    Omanyte      40
# 150                    Omastar      60
# 151                     Kabuto      80
# 152                   Kabutops     115
# 153                 Aerodactyl     105
# 154  AerodactylMega Aerodactyl     135
# 200                  Sudowoodo     100
# 265                   Larvitar      64
# 266                    Pupitar      84
# 267                  Tyranitar     134
# 268    TyranitarMega Tyranitar     164
# 323                   Nosepass      45
# 369                   Lunatone      55
# 370                    Solrock      95
# 377                     Lileep      41
# 378                    Cradily      81
# 379                    Anorith      95
# 380                    Armaldo     125
# 414                   Regirock     100
# ...

# %%
df.loc[(df['Type 1']=='Rock')&(df['Legendary']==True)]
# we can combine more than an attribute as u see here i am displaying all the type rock and are legendary 
# next i will display the same only the name and number in the database
# Out:
#        #                 Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# 414  377             Regirock   Rock       NaN  80     100      200       50
# 700  639            Terrakion   Rock  Fighting  91     129       90       72
# 795  719              Diancie   Rock     Fairy  50     100      150      100
# 796  719  DiancieMega Diancie   Rock     Fairy  50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# 414      100     50           3       True
# 700       90    108           5       True
# 795      150     50           6       True
# 796      110    110           6       True

# %%
df.loc[(df['Type 1']=='Rock')&(df['Legendary']==True),['Name','#']]
# and as u see i displayed them in whatever order i want
# Out:
#                     Name    #
# 414             Regirock  377
# 700            Terrakion  639
# 795              Diancie  719
# 796  DiancieMega Diancie  719

# %%
Fire_heros = df['Type 1']== 'Fire'

# %%
Water_heros = df['Type 1']== 'Water'

# %%
Normal_heros = df['Type 1']== 'Normal'

# %%
Grass_heros = df['Type 1']== 'Grass'

# %%
Bug_heros = df['Type 1']== 'Bug'

# %%
Psychic_heros = df['Type 1']== 'Psychic'

# %%
Electric_heros = df['Type 1']== 'Electric'

# %%
Legendary = df['Legendary']==True

# %%
df.loc[Grass_heros&Legendary]
# Out:
#        #               Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 550  492  ShayminLand Forme  Grass       NaN  100     100      100      100
# 551  492   ShayminSky Forme  Grass    Flying  100     103       75      120
# 701  640           Virizion  Grass  Fighting   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# 550      100    100           4       True
# 551       75    127           4       True
# 701      129    108           5       True

# %%
df.loc[(Grass_heros|Normal_heros)&Legendary]
# Out:
#        #               Name  Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 543  486          Regigigas  Normal       NaN  110     160      110       80
# 550  492  ShayminLand Forme   Grass       NaN  100     100      100      100
# 551  492   ShayminSky Forme   Grass    Flying  100     103       75      120
# 552  493             Arceus  Normal       NaN  120     120      120      120
# 701  640           Virizion   Grass  Fighting   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# 543      110    100           4       True
# 550      100    100           4       True
# 551       75    127           4       True
# 552      120    120           4       True
# 701      129    108           5       True

# %%
df.info()
# the type 2 column has alot of nulls so we will use the fillna method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
np.unique(df['Type 1'])
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
df['Type 2'].fillna(df['Type 1'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      800 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Type 2'].value_counts()
# Out:
# Flying      99
# Water       73
# Psychic     71
# Normal      65
# Grass       58
# Poison      49
# Ground      48
# Fighting    46
# Fire        40
# Fairy       38
# Electric    33
# Dark        30
# Dragon      29
# Steel       27
# Ice         27
# Ghost       24
# Rock        23
# Bug         20
# Name: Type 2, dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# int64     8
# object    3
# bool      1
# dtype: int64

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(['Type 1','HP'])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water   Water  130      65       60      110       95
# 350  320    Wailmer  Water   Water  130      70       35       70       35
# 655  594  Alomomola  Water   Water  165      75       80       40       45
# 351  321    Wailord  Water   Water  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values('Attack',ascending=False)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic   Psychic   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water     Water   20      10       55
# 261  242                  Blissey   Normal    Normal  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal    Normal  250       5        5
# 488  440                  Happiny   Normal    Normal  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
total = df.loc[:,'HP':'Speed'].sum(axis=1)

# %%
total
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Length: 800, dtype: int64

# %%
# df['Mytotal']= df.iloc[:,4:10].sum(axis=1)
df['Mytotal'] = total

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire    Fire  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Mytotal
# 0       65     45           1      False      318
# 1       80     60           1      False      405
# 2      100     80           1      False      525
# 3      120     80           1      False      625
# 4       50     65           1      False      309

# %%
df['Generation'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
df['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
#--------------------

# %%
df.median()
# Out:
# /var/folders/2z/cqy5pg2n25v89hw8bjwkrd5h0000gn/T/ipykernel_14446/530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# #             364.5
# HP             65.0
# Attack         75.0
# Defense        70.0
# Sp. Atk        65.0
# Sp. Def        70.0
# Speed          65.0
# Generation      3.0
# Legendary       0.0
# Mytotal       450.0
# dtype: float64

# %%
df['Type 1'].count()
# Out:
# 800

# %%
df['Type 2'].count()
# Out:
# 800

# %%
df.drop('#',inplace=True,axis=1)

# %%
df.shape
# Out:
# (800, 12)

# %%
df.describe().transpose()
# Out:
#             count       mean         std    min     25%    50%    75%    max
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.0  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.0  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.0  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.0  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.0  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.0  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.0    6.0
# Mytotal     800.0  435.10250  119.963040  180.0  330.00  450.0  515.0  780.0
